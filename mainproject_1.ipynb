# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential 
from keras.layers import Dense,Conv2D,Dropout,Flatten,MaxPooling2D
import os 
import pandas as pd 
import numpy as np

# %%
TRAIN_DIR='images/train'
Test_dir='images/test'

# %%
'''def createdataframe(dir):
    images_paths =[]
    labels =[]
    for labels in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label,"completed")
    return image_paths,labels
    '''
# Out:
# 'def createdataframe(dir):\n    images_paths =[]\n    labels =[]\n    for labels in os.listdir(dir):\n        for imagename in os.listdir(os.path.join(dir,label)):\n            image_paths.append(os.path.join(dir,label,imagename))\n            labels.append(label)\n        print(label,"completed")\n    return image_paths,labels\n    '

# %%
import os
import pandas as pd

# Define paths
TRAIN_DIR = r"C:\Users\Vansh\OneDrive\Desktop\visual stodio\facedetector"
TEST_DIR = r"C:\Users\Vansh\OneDrive\Desktop\visual stodio\facedetector\train"

# Debug: Check if paths exist
print("Train directory exists:", os.path.exists(TRAIN_DIR))
print("Test directory exists:", os.path.exists(TEST_DIR))

def createdataFrame(directory):
    image_paths = []
    labels = []
    for label in os.listdir(directory):
        class_dir = os.path.join(directory, label)
        if os.path.isdir(class_dir):
            for img in os.listdir(class_dir):
                image_paths.append(os.path.join(class_dir, img))
                labels.append(label)
    return image_paths, labels

# Create DataFrames
train = pd.DataFrame()
train['image'], train['label'] = createdataFrame(TRAIN_DIR)

test = pd.DataFrame()
test['image'], test['label'] = createdataFrame(TEST_DIR)

print(train.head())
# Out:
# Train directory exists: True
# Test directory exists: True
#                                                image               label
# 0  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  .ipynb_checkpoints
# 1  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  .ipynb_checkpoints
# 2  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  .ipynb_checkpoints
# 3  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  .ipynb_checkpoints
# 4  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...         archive (1)

# %%
print(test)
print(test['image'])
# Out:
#                                                    image     label
# 0      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 1      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 2      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 3      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 4      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# ...                                                  ...       ...
# 28816  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28817  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28818  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28819  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28820  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
#
# [28821 rows x 2 columns]
# 0        C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 1        C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 2        C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 3        C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 4        C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
#                                ...
# 28816    C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 28817    C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 28818    C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 28819    C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# 28820    C:\Users\Vansh\OneDrive\Desktop\visual stodio\...
# Name: image, Length: 28821, dtype: object

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from tensorflow.keras.utils import load_img
from PIL import Image
# Define paths and create DataFrame
TRAIN_DIR =  r"C:\Users\Vansh\OneDrive\Desktop\visual stodio\facedetector\train" # Replace with your path
train = pd.DataFrame()
train['image'], train['label'] = createdataFrame(TRAIN_DIR)  # Ensure createdataFrame is defined

# Define the feature extraction function
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode='grayscale')  # Correct parameter
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# Extract features
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]

# %%
print(train)
# Out:
#                                                    image     label
# 0      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 1      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 2      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 3      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# 4      C:\Users\Vansh\OneDrive\Desktop\visual stodio\...     angry
# ...                                                  ...       ...
# 28816  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28817  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28818  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28819  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
# 28820  C:\Users\Vansh\OneDrive\Desktop\visual stodio\...  surprise
#
# [28821 rows x 2 columns]

# %%
test_features=extract_features(test['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]

# %%
x_train=train_features/255.0
x_test=test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

# Layer 1
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))  # Fix: "Conv2D", not "Conva2D"
model.add(MaxPooling2D(pool_size=(2,2)))  # Fix: "pool_size=(2,2)"
model.add(Dropout(0.4))

# Layer 2
model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))  # Fix: Use integer 256
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# Layer 3
model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))  # Fix: Use integer 512 instead of "S12"
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# Fully Connected Layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))  # Fix: Use integer 512 instead of "S12"
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(7, activation='softmax'))  # Fix: Added missing closing parenthesis

# %%
model.compile(optimizer ='adam', loss ='categorical_crossentropy',metrics=['accuracy'])
model.fit(x=x_train,y=y_train,batch_size = 128,epochs=50,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 222s 980ms/step - accuracy: 0.2357 - loss: 1.8374 - val_accuracy: 0.3031 - val_loss: 1.7122
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 222s 981ms/step - accuracy: 0.3151 - loss: 1.6872 - val_accuracy: 0.4252 - val_loss: 1.4936
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 216s 955ms/step - accuracy: 0.4182 - loss: 1.5064 - val_accuracy: 0.4725 - val_loss: 1.3617
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 214s 949ms/step - accuracy: 0.4653 - loss: 1.3956 - val_accuracy: 0.5258 - val_loss: 1.2560
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 206s 912ms/step - accuracy: 0.4955 - loss: 1.3327 - val_accuracy: 0.5412 - val_loss: 1.1907
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 206s 914ms/step - accuracy: 0.5080 - loss: 1.2819 - val_accuracy: 0.5714 - val_loss: 1.1319
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 205s 906ms/step - accuracy: 0.5214 - loss: 1.2519 - val_accuracy: 0.5852 - val_loss: 1.1143
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 202s 894ms/step - accuracy: 0.5369 - loss: 1.2081 - val_accuracy: 0.5982 - val_loss: 1.0554
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 196s 867ms/step - accuracy: 0.5506 - loss: 1.1869 - val_accuracy: 0.6162 - val_loss: 1.0480
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 209s 927ms/step - accuracy: 0.5573 - loss: 1.1629 - val_accuracy: 0.6307 - val_loss: 0.9812
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 209s 925ms/step - accuracy: 0.5643 - loss: 1.1522 - val_accuracy: 0.6395 - val_loss: 0.9628
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 216s 957ms/step - accuracy: 0.5757 - loss: 1.1233 - val_accuracy: 0.6464 - val_loss: 0.9523
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 218s 966ms/step - accuracy: 0.5805 - loss: 1.1125 - val_accuracy: 0.6748 - val_loss: 0.8869
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 221s 978ms/step - accuracy: 0.5941 - loss: 1.0726 - val_accuracy: 0.6895 - val_loss: 0.8634
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 214s 947ms/step - accuracy: 0.5982 - loss: 1.0576 - val_accuracy: 0.6839 - val_loss: 0.8563
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 206s 911ms/step - accuracy: 0.5978 - loss: 1.0499 - val_accuracy: 0.7110 - val_loss: 0.8086
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 901ms/step - accuracy: 0.6084 - loss: 1.0274 - val_accuracy: 0.7174 - val_loss: 0.8020
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 897ms/step - accuracy: 0.6189 - loss: 1.0119 - val_accuracy: 0.7303 - val_loss: 0.7738
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 900ms/step - accuracy: 0.6223 - loss: 1.0021 - val_accuracy: 0.7416 - val_loss: 0.7587
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 194s 858ms/step - accuracy: 0.7332 - loss: 0.7188 - val_accuracy: 0.9000 - val_loss: 0.3766
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 191s 845ms/step - accuracy: 0.7405 - loss: 0.7083 - val_accuracy: 0.8941 - val_loss: 0.3777
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 191s 845ms/step - accuracy: 0.7388 - loss: 0.7146 - val_accuracy: 0.9040 - val_loss: 0.3783
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 191s 846ms/step - accuracy: 0.7416 - loss: 0.7001 - val_accuracy: 0.9036 - val_loss: 0.3515
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 191s 847ms/step - accuracy: 0.7439 - loss: 0.6953 - val_accuracy: 0.9104 - val_loss: 0.3362
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 191s 845ms/step - accuracy: 0.7453 - loss: 0.6906 - val_accuracy: 0.9121 - val_loss: 0.3327
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 192s 852ms/step - accuracy: 0.7458 - loss: 0.6932 - val_accuracy: 0.9177 - val_loss: 0.3308
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 192s 851ms/step - accuracy: 0.7565 - loss: 0.6682 - val_accuracy: 0.9218 - val_loss: 0.3221

# %%
# Fully Connected Layers
model.add(Flatten())  # Capitalize "Flatten"
model.add(Dense(512, activation='relu'))  # Replace "S12" with 512, fix "activation" spelling
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))  # Replace "2%" with 256
model.add(Dropout(0.3))
model.add(Dense(7, activation='softmax'))  # Fix "activation" spelling

# Compile the model
model.compile(
    optimizer='adam',  # Replace "admin" with "adam"
    loss='categorical_crossentropy',
    metrics=['accuracy']  # Metrics must be a list
)

# Train the model
model.fit(
    x_train,  # Replace "kmx_train" with "x_train"
    y_train,
    batch_size=128,
    epochs=50,
    validation_data=(x_test, y_test)  # Add parentheses for tuple
)

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 888ms/step - accuracy: 0.7060 - loss: 1.0331 - val_accuracy: 0.9061 - val_loss: 0.3616
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 202s 893ms/step - accuracy: 0.7400 - loss: 0.7624 - val_accuracy: 0.9213 - val_loss: 0.3272
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 201s 890ms/step - accuracy: 0.7467 - loss: 0.7375 - val_accuracy: 0.9138 - val_loss: 0.3281
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 201s 891ms/step - accuracy: 0.7487 - loss: 0.7146 - val_accuracy: 0.9110 - val_loss: 0.3151
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 207s 918ms/step - accuracy: 0.7520 - loss: 0.7061 - val_accuracy: 0.9294 - val_loss: 0.2960
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 208s 923ms/step - accuracy: 0.7512 - loss: 0.7027 - val_accuracy: 0.9312 - val_loss: 0.2866
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 202s 894ms/step - accuracy: 0.7565 - loss: 0.6825 - val_accuracy: 0.9267 - val_loss: 0.2976
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 207s 918ms/step - accuracy: 0.7615 - loss: 0.6807 - val_accuracy: 0.9327 - val_loss: 0.2782
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 900ms/step - accuracy: 0.7663 - loss: 0.6598 - val_accuracy: 0.9260 - val_loss: 0.2999
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 203s 897ms/step - accuracy: 0.7632 - loss: 0.6687 - val_accuracy: 0.9357 - val_loss: 0.2899
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 0.8089 - loss: 0.5529 - val_accuracy: 0.9648 - val_loss: 0.1840
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 208s 924ms/step - accuracy: 0.8066 - loss: 0.5543 - val_accuracy: 0.9655 - val_loss: 0.1901
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 207s 918ms/step - accuracy: 0.8102 - loss: 0.5434 - val_accuracy: 0.9684 - val_loss: 0.1798
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 215s 951ms/step - accuracy: 0.8083 - loss: 0.5439 - val_accuracy: 0.9658 - val_loss: 0.1758
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 221s 980ms/step - accuracy: 0.8117 - loss: 0.5388 - val_accuracy: 0.9633 - val_loss: 0.1666
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 225s 999ms/step - accuracy: 0.8162 - loss: 0.5405 - val_accuracy: 0.9668 - val_loss: 0.1777
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 341s 2s/step - accuracy: 0.8137 - loss: 0.5331 - val_accuracy: 0.9646 - val_loss: 0.1795
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.8145 - loss: 0.5309 - val_accuracy: 0.9690 - val_loss: 0.1738
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 401s 2s/step - accuracy: 0.8160 - loss: 0.5331 - val_accuracy: 0.9709 - val_loss: 0.1606
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 449s 2s/step - accuracy: 0.8164 - loss: 0.5274 - val_accuracy: 0.9714 - val_loss: 0.1650
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 450s 2s/step - accuracy: 0.8212 - loss: 0.5186 - val_accuracy: 0.9715 - val_loss: 0.1570
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 369s 2s/step - accuracy: 0.8190 - loss: 0.5143 - val_accuracy: 0.9678 - val_loss: 0.1807
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.8254 - loss: 0.5079 - val_accuracy: 0.9757 - val_loss: 0.1664
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.8242 - loss: 0.5115 - val_accuracy: 0.9718 - val_loss: 0.1595
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.8225 - loss: 0.5133 - val_accuracy: 0.9616 - val_loss: 0.1931
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 424s 2s/step - accuracy: 0.8118 - loss: 0.5370 - val_accuracy: 0.9716 - val_loss: 0.1439
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.8282 - loss: 0.4933 - val_accuracy: 0.9751 - val_loss: 0.1475

# %%
model_json = model.to_json()
with open("emotiondetector.json","w") as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json","r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,color_mode='grayscale')
    feature = img_to_array(img)
    feature=feature.reshape(1,48,48,1)
    return feature

# %%
from tensorflow.keras.utils import load_img,img_to_array
image = r'C:\Users\Vansh\OneDrive\Desktop\visual stodio\facedetector\test\disgust\573.jpg'
print("the orignal image is --")
img = ef(image)
pred = model.predict(img)
pred_label=label[pred.argmax()]
print("model prediction is =",pred_label)
# Out:
# the orignal image is --
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# model prediction is = disgust
